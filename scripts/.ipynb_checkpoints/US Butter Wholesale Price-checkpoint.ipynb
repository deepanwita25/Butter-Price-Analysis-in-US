# %%
import pandas as pd
from pathlib import Path
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\deepa\\OneDrive - DSTI School of Engineering\\Desktop\\UDEMY_Projects\\Butter-Price-Analysis-in-US\\scripts'
